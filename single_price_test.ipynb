# %%
#Auto reload
# %reload_ext autoreload
# %autoreload 2

from BaseModel import BaseModel
from DeterministicModel import DeterministicModel
from HAPDModel import HAPDModel
from HindsightModel import HindsightModel
from evaluation import *
from utils import *

# %%
hapd = HAPDModel('HAPD_single_price',HOURS_PER_YEAR)
hapd.train(training_length=HOURS_PER_YEAR)
results = hapd.evaluate(HOURS_PER_YEAR)
get_total_objective(results)
# Out:
# Model HAPD_single_price
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 50
# Number of features: 6
# Test start index: 8640
# Weights successfully saved
# 1819134.4262018087

# %%
hindsight = HindsightModel('Hindsight_single_price',HOURS_PER_YEAR)
deterministic = DeterministicModel('Deterministic_single_price',HOURS_PER_YEAR)
hapd = HAPDModel('HAPD_single_price',HOURS_PER_YEAR)
hapd.load_from_weights()
# Out:
# Model Hindsight_single_price
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 50
# Number of features: 6
# Test start index: 8640
# Model Deterministic_single_price
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 50
# Number of features: 6
# Test start index: 8640
# Model HAPD_single_price
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 50
# Number of features: 6
# Test start index: 8640
# Weights successfully loaded

# %%
models = [hindsight, deterministic, hapd]
results = []

for model in models:
    result = model.evaluate(HOURS_PER_YEAR)
    print(model.name)
    print(get_total_objective(result))
    results.append(result)
    model.save_results(result)
# Out:
# Hindsight_single_price
# 3498100.211764706
# Results saved successfully.
# Deterministic_single_price
# 1793865.3379165393
# Results saved successfully.
# HAPD_single_price
# 1819134.4262018087
# Results saved successfully.

# %%
total_results = []
for model,result in zip(models, results):
    aux = [result, model.rule_based_adjustment(result), model.MPC_adjustment(result),model.best_adjustment(result)]
    total_results.append(aux)
    print(f"Model: {model.name} done")
# Out:
# Model: Hindsight_single_price done
# Model: Deterministic_single_price done
# Model: HAPD_single_price done

# %%
for model, result in zip(models, total_results):
    model.save_results(result[0], 'original')
    model.save_results(result[1], 'rule_based_adj')
    model.save_results(result[2], 'MPC_adj')
    model.save_results(result[3], 'best_adj')
# Out:
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.

# %%
plot_objectives(total_results, ['Hindsight', 'Deterministic', 'HAPD'],'Objectives for each model (H_Min = 50)')

# %%
for h_min in [50, 100, 150, 200]:
    hindsight_model = HindsightModel(f'Hindsight_hmin{h_min}', HOURS_PER_YEAR, h_min=h_min)
    deterministic_model = DeterministicModel(f'Deterministic_hmin{h_min}', HOURS_PER_YEAR, h_min=h_min)
    hapd_model = HAPDModel(f'HAPD_hmin{h_min}', HOURS_PER_YEAR, h_min=h_min)
    hapd_model.train(training_length=HOURS_PER_YEAR)
    models = [hindsight_model, deterministic_model, hapd_model]
    results = []

    for model in models:
        result = model.evaluate(HOURS_PER_YEAR)
        print(model.name)
        print(get_total_objective(result))
        results.append(result)
        
    total_results = []
    for model,result in zip(models, results):
        aux = [result, model.rule_based_adjustment(result), model.MPC_adjustment(result),model.best_adjustment(result)]
        total_results.append(aux)
        print(f"Model: {model.name} done")

    for model, result in zip(models, total_results):
        model.save_results(result[0], 'original')
        model.save_results(result[1], 'rule_based_adj')
        model.save_results(result[2], 'MPC_adj')
        model.save_results(result[3], 'best_adj')
    plot_objectives(total_results, ['Hindsight', 'Deterministic', 'HAPD'],f'Objectives for each model (H_Min = {h_min})')
# Out:
# Model Hindsight_hmin50
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 50
# Number of features: 6
# Test start index: 8640
# Model Deterministic_hmin50
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 50
# Number of features: 6
# Test start index: 8640
# Model HAPD_hmin50
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 50
# Number of features: 6
# Test start index: 8640
# Weights successfully saved
# Hindsight_hmin50
# 3498100.211764706
# Deterministic_hmin50
# 1793865.3379165393
# HAPD_hmin50
# 1819134.4262018087
# Model: Hindsight_hmin50 done
# Model: Deterministic_hmin50 done
# Model: HAPD_hmin50 done
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Model Hindsight_hmin100
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 100
# Number of features: 6
# Test start index: 8640
# Model Deterministic_hmin100
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 100
# Number of features: 6
# Test start index: 8640
# Model HAPD_hmin100
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 100
# Number of features: 6
# Test start index: 8640
# Weights successfully saved
# Hindsight_hmin100
# 3483112.011764706
# Deterministic_hmin100
# 1774025.3379165393
# HAPD_hmin100
# 1776283.2184061436
# Model: Hindsight_hmin100 done
# Model: Deterministic_hmin100 done
# Model: HAPD_hmin100 done
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Model Hindsight_hmin150
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 150
# Number of features: 6
# Test start index: 8640
# Model Deterministic_hmin150
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 150
# Number of features: 6
# Test start index: 8640
# Model HAPD_hmin150
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 150
# Number of features: 6
# Test start index: 8640
# Weights successfully saved
# Hindsight_hmin150
# 3410046.311764706
# Deterministic_hmin150
# 1705573.3379165393
# HAPD_hmin150
# 1674220.2563002915
# Model: Hindsight_hmin150 done
# Model: Deterministic_hmin150 done
# Model: HAPD_hmin150 done
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Model Hindsight_hmin200
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 200
# Number of features: 6
# Test start index: 8640
# Model Deterministic_hmin200
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 200
# Number of features: 6
# Test start index: 8640
# Model HAPD_hmin200
# Nominal wind: 10
# Max wind: 10
# Max hydrogen: 10
# H min: 200
# Number of features: 6
# Test start index: 8640
# Weights successfully saved
# Hindsight_hmin200
# 3190464.711764706
# Deterministic_hmin200
# 1585430.3379165393
# HAPD_hmin200
# 1545023.0262018084
# Model: Hindsight_hmin200 done
# Model: Deterministic_hmin200 done
# Model: HAPD_hmin200 done
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
# Results saved successfully.
